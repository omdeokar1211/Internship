# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ds= pd.read_csv("employee_dataset_for_eda.csv")
ds
# Out:
#      Employee_ID  Age  Gender   Department       Location  \
# 0           1001   50  Female    Marketing         Austin
# 1           1002   36  Female        Sales       New York
# 2           1003   29    Male    Marketing  San Francisco
# 3           1004   42  Female           HR  San Francisco
# 4           1005   40  Female    Marketing         Austin
# ..           ...  ...     ...          ...            ...
# 195         1196   40  Female           HR       New York
# 196         1197   41    Male      Finance  San Francisco
# 197         1198   53    Male           HR       New York
# 198         1199   28  Female           HR         Austin
# 199         1200   54    Male  Engineering         Austin
#
#      Years_of_Experience  Monthly_Salary  Performance_Score
# 0                      4          105046               79.6
# 1                      1           59287               71.7
# 2                      5           69711               87.2
# 3                      1           41954               74.4
# 4                     12          103340               82.5
# ..                   ...             ...                ...
# 195                   12           93230               67.3
# 196                    9          104055               58.3
# 197                   17           86373               62.6
# 198                    7           61480               60.7
# 199                    7          115230               75.9
#
# [200 rows x 8 columns]

# %%
ds.head(10)
# Out:
#    Employee_ID  Age  Gender   Department       Location  Years_of_Experience  \
# 0         1001   50  Female    Marketing         Austin                    4
# 1         1002   36  Female        Sales       New York                    1
# 2         1003   29    Male    Marketing  San Francisco                    5
# 3         1004   42  Female           HR  San Francisco                    1
# 4         1005   40  Female    Marketing         Austin                   12
# 5         1006   44    Male  Engineering       New York                   10
# 6         1007   32    Male  Engineering        Seattle                   10
# 7         1008   32  Female           HR        Seattle                   15
# 8         1009   45    Male        Sales  San Francisco                   10
# 9         1010   57    Male  Engineering       New York                   18
#
#    Monthly_Salary  Performance_Score
# 0          105046               79.6
# 1           59287               71.7
# 2           69711               87.2
# 3           41954               74.4
# 4          103340               82.5
# 5          102101               74.2
# 6          101520               67.2
# 7          117062               59.4
# 8           48574               64.0
# 9           39184               67.4

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee_ID          200 non-null    int64
#  1   Age                  200 non-null    int64
#  2   Gender               200 non-null    object
#  3   Department           200 non-null    object
#  4   Location             200 non-null    object
#  5   Years_of_Experience  200 non-null    int64
#  6   Monthly_Salary       200 non-null    int64
#  7   Performance_Score    200 non-null    float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 12.6+ KB

# %%
ds.duplicated().sum()
# Out:
# 0

# %%
sns.countplot(data=ds,x='Department',palette='Set2')
plt.title('Employeee count per Department')
# Out:
# C:\Users\omdeo\AppData\Local\Temp\ipykernel_27380\2921907220.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Department',palette='Set2')
# Text(0.5, 1.0, 'Employeee count per Department')

# %% [markdown]
# Finance department having more empolyee count followed by marketing and engineering

# %%
#gender distribution
sns.countplot(data=ds,x='Gender',palette='coolwarm')
plt.title('Gender Distribution')
# Out:
# C:\Users\omdeo\AppData\Local\Temp\ipykernel_27380\1593279335.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Gender',palette='coolwarm')
# Text(0.5, 1.0, 'Gender Distribution')

# %% [markdown]
# Femele employee count is more then mele count

# %%
#employee location distribution
sns.countplot(data=ds,x='Location',palette='Spectral')
plt.title('Number of employeee by location')
plt.xticks(rotation=45)
# Out:
# C:\Users\omdeo\AppData\Local\Temp\ipykernel_27380\2983065168.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ds,x='Location',palette='Spectral')
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Austin'),
#   Text(1, 0, 'New York'),
#   Text(2, 0, 'San Francisco'),
#   Text(3, 0, 'Seattle'),
#   Text(4, 0, 'Chicago')])

# %% [markdown]
# number of employee is seatle is more follwed by new yark and San Francisco

# %%
#Age Distribution

sns.histplot(ds['Age'],bins=10,kde=True)
plt.title('Age distribution')
# Out:
# Text(0.5, 1.0, 'Age distribution')

# %% [markdown]
# employee in 40-45 years are more followed by 25-30

# %%
sns.histplot(ds['Years_of_Experience'],bins=15,kde=True)
plt.title('Years_of_Experience')
# Out:
# Text(0.5, 1.0, 'Years_of_Experience')

# %% [markdown]
# 2.5-5.0 years experience employeee are more then other years of experience employes

# %%
sns.boxplot(data=ds, y='Monthly_Salary', color='lightblue')
plt.title('Salary Seprated')
# Out:
# Text(0.5, 1.0, 'Salary Seprated')

# %% [markdown]
# 20000 is minimum salary and maximum salary is distributed and 750000 is average salary for distributed

# %%
#average salary by department
sns.barplot (data=ds,x='Department', y='Monthly_Salary', estimator=np.mean , palette='viridis')
plt.title("average salary by department")
# Out:
# C:\Users\omdeo\AppData\Local\Temp\ipykernel_27380\4211328242.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot (data=ds,x='Department', y='Monthly_Salary', estimator=np.mean , palette='viridis')
# Text(0.5, 1.0, 'average salary by department')

# %% [markdown]
# Finance department having more avarage Salary

# %%
sns.boxplot(data=ds, x='Department', y='Performance_Score', palette='pastel')
plt.title('Salary by Gender')
# Out:
# C:\Users\omdeo\AppData\Local\Temp\ipykernel_27380\552069140.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=ds, x='Department', y='Performance_Score', palette='pastel')
# Text(0.5, 1.0, 'Salary by Gender')

# %%
#Salary Distibution by Gender
sns.violinplot(data=ds, x='Gender', y='Monthly_Salary', palette='muted')
plt.title('Salary by Gender')
# Out:
# C:\Users\omdeo\AppData\Local\Temp\ipykernel_27380\2660976527.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=ds, x='Gender', y='Monthly_Salary', palette='muted')
# Text(0.5, 1.0, 'Salary by Gender')

# %%
sns.heatmap(ds[['Age','Years_of_Experience','Monthly_Salary','Performance_Score']].corr(),annot=True,cmap='coolwarm')
plt.title('Correlation matrix')
# Out:
# Text(0.5, 1.0, 'Correlation matrix')

# %%
sns.scatterplot(data=ds, x='Years_of_Experience',y='Monthly_Salary', hue='Department')
plt.title('Salery vs Exp by dept')
# Out:
# Text(0.5, 1.0, 'Salery vs Exp by dept')
